# %% [markdown]
# # Analyze HF dataset

# %%
from datasets import load_dataset
import pandas as pd

# %%
amath_dset = load_dataset("MARIO-Math-Reasoning/AlphaMath-Trainset", split="train")
amath_dset
# Out:
# Dataset({
#     features: ['answer', 'id', 'output', 'instruction', 'input'],
#     num_rows: 115551
# })

# %%
amath_df = pd.DataFrame(amath_dset)
amath_df
# Out:
#              answer         id  \
# 0               234  gsm8k_525
# 1               234  gsm8k_525
# 2               234  gsm8k_525
# 3               234  gsm8k_525
# 4               234  gsm8k_525
# ...             ...        ...
# 115546  \frac{1}{7}  math_2325
# 115547         2005  math_4610
# 115548         2005  math_4610
# 115549         2005  math_4610
# 115550         2005  math_4610
#
#                                                    output  \
# 0       [{"step": "<step>\n<p>\nTo find how many books...
# 1       [{"step": "<step>\n<p>\nTo find how many books...
# 2       [{"step": "<step>\n<p>\nTo calculate how many ...
# 3       [{"step": "<step>\n<p>\nTo find the number of ...
# 4       [{"step": "<step>\n<p>\nTo solve this problem,...
# ...                                                   ...
# 115546  [{"step": "<step>\n<p>\nThe color of the light...
# 115547  [{"step": "<step>\n<p>\nTo find the sum of the...
# 115548  [{"step": "<step>\n<p>\nTo find the sum of the...
# 115549  [{"step": "<step>\n<p>\nTo find the sum of the...
# 115550  [{"step": "<step>\n<p>\nTo find the sum of the...
#
#                                               instruction input
# 0       <question> There are 336 books in a library. O...
# 1       <question> There are 336 books in a library. O...
# 2       <question> There are 336 books in a library. O...
# 3       <question> There are 336 books in a library. O...
# 4       <question> There are 336 books in a library. O...
# ...                                                   ...   ...
# 115546  <question> A traffic light runs repeatedly thr...
# 115547  <question> Find the sum of the $2007$ roots of...
# 115548  <question> Find the sum of the $2007$ roots of...
# 115549  <question> Find the sum of the $2007$ roots of...
# 115550  <question> Find the sum of the $2007$ roots of...
#
# [115551 rows x 5 columns]
